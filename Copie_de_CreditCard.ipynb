# %% [markdown]
# <a href="https://colab.research.google.com/github/hamel-amir/Projet_Machine_learning/blob/main/Copie_de_CreditCard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Séance 1 : Analyse exploratoire des données déséquilibrées***

# %% [markdown]
# **Préparation de l'environnement**

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install scikit-plot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install plot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.1/135.1 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26321 sha256=a397e95053967ab807a945b5ecae847f95fcbd8d2854f1b5e5f286b3f741c9d3
#   Stored in directory: /root/.cache/pip/wheels/fa/17/1f/332799f975d1b2d7f9b3f33bbccf65031e794717d24432caee
# Successfully built typing
# ...

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install fast-ml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 2.3 MB/s eta 0:00:00
# ...

# %%
# !pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **importation du dataset Creditcard**

# %%
#from numpy import np
import pandas as pd
df = pd.read_csv('/content/creditcard.csv')

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
# les dimensions du dataset
df.shape
# Out:
# (178374, 31)

# %% [markdown]
# ce dataset contient 31 variables dont : 30 features et le target (class)

# %%
# les attributs(features) du dataset
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# summury
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  178374.000000  178374.000000  178374.000000  178374.000000
# mean    63649.526966      -0.150143       0.028160       0.442686
# std     29852.613589       1.867263       1.612863       1.406196
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     42012.000000      -0.979289      -0.554048      -0.136748
# 50%     62466.000000      -0.153568       0.099331       0.589319
# 75%     80529.000000       1.192764       0.795729       1.277279
# max    123602.000000       2.439207      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  178374.000000  178374.000000  178374.000000  178374.000000
# mean        0.102605      -0.159387       0.055397      -0.073182
# std         1.380570       1.350839       1.301615       1.213596
# min        -5.519697     -42.147898     -26.160506     -43.557242
# ...

# %% [markdown]
# D'après la méthode Describe qui nous permet de voir quelques statistiques (moyenne, écart-type, médiane, min, max ) nous observons que les variables V1 jusqu'au V28 sont déja mises à l'échelle et par contre les variables Time et Amount ne sont pas .

# %% [markdown]
# **Vérification des valeurs manquantes**

# %%
# Vérification des valeurs manquantes
if df.isnull().values.any():
    print("Le DataFrame contient des valeurs manquantes.")
else:
    print("Le DataFrame ne contient pas de valeurs manquantes.")
# Out:
# Le DataFrame contient des valeurs manquantes.

# %% [markdown]
#  Il n’y a pas de valeurs "nulles", donc nous n’avons pas à travailler sur des façons de remplacer les valeurs.

# %% [markdown]
# **Classes Déséquilibrées**

# %% [markdown]
# La plupart des transactions (observations) sont non frauduleuses (99,83 %), tandis que les transactions frauduleuses se produisent (017 %) dans le dataframe.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
colors = ["#0101DF", "#DF0101"]

sns.countplot(x='Class', data=df, palette=colors)
plt.title('Class Distributions \n (0: No Fraud || 1: Fraud)', fontsize=14)
print('No Frauds', round(df['Class'].value_counts()[0]/len(df) * 100,2), '% of the dataset')
print('Frauds', round(df['Class'].value_counts()[1]/len(df) * 100,2), '% of the dataset')
# Out:
# No Frauds 99.8 % of the dataset
# Frauds 0.2 % of the dataset

# %% [markdown]
# **Visualisation de la distribution des valeurs des deux variables Amount et Time**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(18,4))
amount_val = df['Amount'].values
time_val = df['Time'].values

sns.distplot(amount_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.distplot(time_val, ax=ax[1], color='b')
ax[1].set_title('Distribution of Transaction Time', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])



plt.show()
# Out:
# <ipython-input-15-2b107695cba4>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(amount_val, ax=ax[0], color='r')
# <ipython-input-15-2b107695cba4>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(time_val, ax=ax[1], color='b')

# %% [markdown]
# cette visualisation nous donne une idée a quel point ces deux variables ne sont pas mises a l'echelles

# %% [markdown]
# **Mettre a l'échelles les variables Amount et Time**

# %% [markdown]
# Étant donné que la plupart de nos données ont déjà été mises à l’échelle, nous devrions mettre à l’échelle les colonnes qui sont laissées à l’échelle (Amount et Time).

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler


std_scaler = StandardScaler()
rob_scaler = RobustScaler()

df['scaled_amount'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1,1))

df.drop(['Time','Amount'], axis=1, inplace=True)

scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']

df.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(1, 'scaled_time', scaled_time)

# Amount and Time are Scaled!

df.head()
# Out:
#    scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0       1.765536    -1.621777 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.268097    -1.621777  1.191857  0.266151  0.166480  0.448154
# 2       4.935640    -1.621751 -1.358354 -1.340163  1.773209  0.379780
# 3       1.404014    -1.621751 -0.966272 -0.185226  1.792993 -0.863291
# 4       0.663391    -1.621725 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %% [markdown]
# **Visualisation de Time et Amount aprés la mise a l'échelle**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(18,4))
amount_val = df['scaled_amount'].values
time_val = df['scaled_time'].values

sns.distplot(amount_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.distplot(time_val, ax=ax[1], color='b')
ax[1].set_title('Distribution of Transaction Time', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])



plt.show()
# Out:
# <ipython-input-17-1f45c6331af3>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(amount_val, ax=ax[0], color='r')
# <ipython-input-17-1f45c6331af3>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(time_val, ax=ax[1], color='b')

# %% [markdown]
# **Détection et traitements des valeurs aberrantes pour chaque variable**

# %%
def find_outliers_IQR(df):
   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers

# passer une variable en parametre de la fonction
outliers=find_outliers_IQR(df['V10'])
print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))
# Out:
# number of outliers: 6794
# max outlier value: 23.7451361206545
# min outlier value: -24.5882624372475

# %%
#plt.figure(figsize=(20,8));
import seaborn as snb
def Box_plot(column):
  snb.boxplot(x= df[column]);

Box_plot(df.columns[14])

# %% [markdown]
# **Remarque :** Le traitement des valeurs aberrantes va supprimer des lignes et il est fort possible que les transactions de la classe minoritaire (1) serent etre supprimeées ce qui va influencer négativement sur les resultats des modeles de classification

# %%
# def outliers_cleaning(column):
#    q1=df[column].quantile(0.25)

#    q3=df[column].quantile(0.75)

#    IQR=q3-q1
#    mask=(df[column]<(q1-1.5*IQR)) | (df[column]>(q3+1.5*IQR))
   
#    return df.loc[~mask]
# F=outliers_cleaning('V14')
# df=F.copy()
# Box_plot(df.columns[14])
# df

# %% [markdown]
# **Vérification des attribus constant**

# %%
# Attribut constant
from fast_ml.utilities import display_all
from fast_ml.feature_selection import get_constant_features
constant_features=get_constant_features(df)
constant=constant_features.loc[constant_features['Desc']=="Constant"]
if len(constant)==0:
  print("ya pas d'attributs constants")
else:
   print(constant)
# Out:
# ya pas d'attributs constants

# %% [markdown]
# **Vérification des attribus quasi-constant**

# %%
# Attributs # Attribut quasi constant
unique_counts = df.nunique()
value_counts = unique_counts/len(df)
constant_columns = value_counts[value_counts < 0.01].index.tolist()
constant_columns
# Out:
# ['Class']

# %% [markdown]
# **Les histogrammes churn vs churn**

# %%
import matplotlib.pyplot as plt

# liste des variables numériques
plt.figure(figsize=(30, 30))
num_vars = df.columns
nbr=len(num_vars) # nombre de variables
#print(nbr)
#print(df.dtypes)
# Pour chaque variable numérique, créer un sous-graphique avec deux histogrammes
for i, var in enumerate(num_vars):
    plt.subplot(16,2,i+1)
    df[df['Class'] == 1][var].hist(alpha=0.5, bins=20, label='Churn(fraud)')
    df[df['Class'] == 0][var].hist(alpha=0.5, bins=20, label='Non churn (non fraud)')
    plt.legend(loc='upper right')
    plt.title(var)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Matrice de correlatrion entre les variables numériques**

# %% [markdown]
# cette matrice nous aide a bien comprendre les données et les relations entres les variables ainsi que detecter les variables qui influencent fortement sur la classe

# %%
# Matrice de correlation
# Compute the correlation matrix
corr = df.corr()
corr
# Out:
#                scaled_amount  scaled_time        V1        V2        V3  \
# scaled_amount       1.000000    -0.016057 -0.234848 -0.545010 -0.200637
# scaled_time        -0.016057     1.000000  0.088891 -0.002787 -0.270573
# V1                 -0.234848     0.088891  1.000000 -0.018935  0.094615
# V2                 -0.545010    -0.002787 -0.018935  1.000000 -0.076027
# V3                 -0.200637    -0.270573  0.094615 -0.076027  1.000000
# V4                  0.093774    -0.065257 -0.027076  0.033784 -0.039424
# V5                 -0.378183     0.120956  0.021792 -0.033352  0.083718
# V6                  0.201716    -0.037477  0.034634  0.010229 -0.036328
# V7                  0.359693     0.053679  0.075071 -0.019459  0.138564
# V8                 -0.089057    -0.034774  0.006191 -0.015934 -0.041036
# V9                 -0.030659     0.013739 -0.009919 -0.000631  0.027557
# V10                -0.112097     0.026670 -0.003687  0.015089  0.071320
# ...

# %%
# Heatmap correlation
import seaborn as sns
import matplotlib.pyplot as plt
# Définir la taille de la figure
plt.figure(figsize=(15, 15))

# Create heatmap
sns.heatmap(corr,cmap='YlGnBu', annot=True, fmt=".2f", linewidths=.5)

# Ajuster la taille de la police des annotations
plt.rc('font', size=12)

# Ajuster la densité des annotations
plt.yticks(rotation=0)
plt.xticks(rotation=90)

# Afficher la heatmap agrandie
plt.show()

# %% [markdown]
# D'apres la matrice de corrélation on remarques:
# *  des variables qui ont une corrélation négative avec la classe telles que : V17, V14, V12 et V10, autrement dit plus ces variables sont faible , plus la classe est positive ==1 ( fraud).
#
# * des variables qui ont une corrélation positive avec la classe telles que : V2, V4, V11 et V19, autrement dit plus ces variables sont élevées , plus la classe est positive ==1 ( fraud).

# %% [markdown]
# **Visualisation des variables qui sont négativement corréleés avec la classe**

# %%
f, axes = plt.subplots(ncols=4, figsize=(20,4))
# Negative Correlations with our Class (The lower our feature value the more likely it will be a fraud transaction)
sns.boxplot(x="Class", y="V17", data=df, palette=colors, ax=axes[0])
axes[0].set_title('V17 vs Class Negative Correlation')

sns.boxplot(x="Class", y="V14", data=df, palette=colors, ax=axes[1])
axes[1].set_title('V14 vs Class Negative Correlation')


sns.boxplot(x="Class", y="V12", data=df, palette=colors, ax=axes[2])
axes[2].set_title('V12 vs Class Negative Correlation')


sns.boxplot(x="Class", y="V10", data=df, palette=colors, ax=axes[3])
axes[3].set_title('V10 vs Class Negative Correlation')

plt.show()

# %% [markdown]
# **Visualisation des variables qui sont positivement corréleés avec la classe**

# %%
f, axes = plt.subplots(ncols=4, figsize=(20,4))
sns.boxplot(x="Class", y="V11", data=df, palette=colors, ax=axes[0])
axes[0].set_title('V11 vs Class Positive Correlation')

sns.boxplot(x="Class", y="V4", data=df, palette=colors, ax=axes[1])
axes[1].set_title('V4 vs Class Positive Correlation')


sns.boxplot(x="Class", y="V2", data=df, palette=colors, ax=axes[2])
axes[2].set_title('V2 vs Class Positive Correlation')


sns.boxplot(x="Class", y="V19", data=df, palette=colors, ax=axes[3])
axes[3].set_title('V19 vs Class Positive Correlation')

plt.show()

# %% [markdown]
# **Séance 2: Prédiction de churn, Partie I**

# %% [markdown]
# **Les modeles de classification**

# %% [markdown]
# **Partitionnement de l'ensemble de données en Trainset et Testset**

# %%
from sklearn.model_selection import train_test_split
Y=df['Class'] # target
mask=df.columns.shape[0]
features=df.columns[:mask-1]
X=df[features] # features

X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=1, train_size = .7, stratify=Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ab6554c82a62> in <cell line: 7>()
#       5 X=df[features] # features
#       6
# ----> 7 X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=1, train_size = .7, stratify=Y)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2581         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2582
# -> 2583         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2584
#    2585     return list(
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    2158         to an integer.
#    2159         """
# -> 2160         y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
# ...

# %%
# X_train=X_train[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']]

# X_test=X_test[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']]

# %% [markdown]
# Fonction qui construit la matrice de confusion

# %%
import itertools
import numpy as np

# Create a confusion matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print(" ")
    else:
        print(' ')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# **Remarque :**
# Etant données que les classes du dataset sont déséquilibrées et que la classe majoritaite est 0 (non-fraud).

# %% [markdown]
# **Arbre de décision**

# %%
from sklearn import tree
from sklearn import metrics
clf = tree.DecisionTreeClassifier()
# fit model
clf = clf.fit(X_train, y_train)
#tree.plot_tree(clf)
# predict model
y_pred=clf.predict(X_test)
y_pred

# %% [markdown]
# **les métriques d'évaluation de performances des modeles**

# %%
metrics.confusion_matrix(y_test,y_pred)
import scikitplot as skplt
skplt.metrics.plot_confusion_matrix(y_test, y_pred)

# %% [markdown]
# D'apres la matrice de confusion on remarque que :
#
# * TP ( true positive ) = 118 , le nombre d'instance positives (fraud) qui ont été predites positive
#
# * TN ( true negative ) = 85253 , le nombre d'instances negatives ( classe=0 non-fraud) qui ont été predites negatives
#
# * FN (false negative) = 42, le nombre d'instances negatives( classe=0) qui ont été predites positives (incorrecte).
#
# * FN (false positive )= 31, le nombre d'instances positive( classe=1) qui ont été predites negative.

# %%
def metrics_evaluation(y_test,y_pred):
  # Model Accuracy, how often is the classifier correct?
  print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("--------------------------------------------------")
  print("Recall:",metrics.recall_score(y_test, y_pred))
  print("--------------------------------------------------")
  print("precision:",metrics.precision_score(y_test, y_pred))
  print("--------------------------------------------------")
  print("f1_score:",metrics.f1_score(y_test, y_pred))
  print("--------------------------------------------------")
  
metrics_evaluation(y_test,y_pred)

# %% [markdown]
# D'aprés les résultats des mesures de performances qu'on a obtenu , on peut constater que nore modele est bon en terme  :
#
# * accuracy ( le taux d'observation predites correctement ) = 0.999
#
# *  Recall ( la proportion d'observation positive qui'ont été predit correctement ) = 0.7972
#
# * precision_score : la proportion d’observation positifs prédit qui sont réellement positif = 0.737
#
# * f1_score:  est la moyenne du rappel et de la précision , un score plus élevé étant un meilleur modèle = 0.766
# mais  ça ne représente pas la réalité de notre dataset car les classes sont désequilibrés et ya une sur presentation de la classe 0 par rapport a la classe 1 et cela va entrainer des impacts sur la performance du modele predictif .

# %%
def curbe_ROC(y_test,y_pred):
  fpr_RF, tpr_RF, thresholds_RF = metrics.roc_curve(y_test,y_pred)
  import matplotlib.pyplot as plt
  # AUC
  auc_RF = metrics.roc_auc_score(y_test,y_pred)

  plt.plot(fpr_RF, tpr_RF,'k-',label = f'AUC =({auc_RF})')
  # plt.plot([0,1],[0,1],'r-',label='random model')
  # plt.plot([0,0,1,1],[0,1,1,1],'g-',label='perfect model')
  plt.title('ROC Curve', fontsize=16)
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()
  
curbe_ROC(y_test,y_pred)

# %% [markdown]
# **Régression logistique**

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='lbfgs', max_iter=3000)
log_reg.fit(X_train, y_train)
pred = log_reg.predict(X_test)

# %% [markdown]
# **matrice de confusion**

# %%
import scikitplot as skplt
skplt.metrics.plot_confusion_matrix(y_test, pred)

# %% [markdown]
# D'apres la matrice de confusion on remarque que :
#
# * TP ( true positive ) = 102 , le nombre d'instance positives (fraud) qui ont été predites positive
#
# * TN ( true negative ) = 85284 , le nombre d'instances negatives ( classe=0 non-fraud) qui ont été predites negatives
#
# * FP (false negative) = 11, le nombre d'instances negatives( classe=0) qui ont été predites positives
#
# * FN (false positive )= 46, le nombre d'instances positive( classe=1) qui ont été predites negative.

# %%
metrics_evaluation(y_test, pred)

# %%
curbe_ROC(y_test,pred)

# %% [markdown]
# **SVM (sans kernel)**
#
# comme les variables Time et Amount sont moins faible et ont une faible influence sur la classe par rapport au autres variables , on les a enlevé lors du l'entrainelent du modele SVM car celui-ci prend beacoup de temps avec toutes les variables passés.

# %%
X_train_svm=X_train[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']]
X_test_svm=X_test[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']]

# %%
from sklearn.svm import SVC 
# "Support vector classifier"
model = SVC ()
model.fit(X_train_svm, y_train)

# %%
svm_pred=model.predict(X_test_svm)

# %%
metrics_evaluation(y_test, svm_pred)

# %%
curbe_ROC(y_test, svm_pred)

# %% [markdown]
# **Comparaison les différentes approches (modeles)**

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
tree = metrics.confusion_matrix(y_test, y_pred)
log = metrics.confusion_matrix(y_test, pred)
svm= metrics.confusion_matrix(y_test, svm_pred)
labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

fig.add_subplot(221)
plot_confusion_matrix(tree, labels, title="Confusion Matrix \n ( Decision Tree)", cmap=plt.cm.Reds)

fig.add_subplot(222)
plot_confusion_matrix(log, labels, title="Confusion Matrix \n (Logistic Regression)", cmap=plt.cm.Greens)

fig.add_subplot(223)
plot_confusion_matrix(svm, labels, title="Confusion Matrix \n (SVM ) sans kernel", cmap=plt.cm.Greens)

# %%
X = [
        [metrics.accuracy_score(y_test, y_pred),metrics.recall_score(y_test, y_pred), metrics.precision_score(y_test, y_pred), metrics.f1_score(y_test, y_pred)],
        [metrics.accuracy_score(y_test, pred),metrics.recall_score(y_test, pred),metrics.precision_score(y_test, pred), metrics.f1_score(y_test, pred)],
        [metrics.accuracy_score(y_test, svm_pred), metrics.recall_score(y_test, svm_pred), metrics.precision_score(y_test, svm_pred),metrics.f1_score(y_test, svm_pred)],
         
        
    ]
resultat = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['Decision Tree','Logistic regression','SVC(sans kernel)'])
resultat

# %%
  fpr_RF, tpr_RF, thresholds_RF = metrics.roc_curve(y_test,y_pred)
  pred_fpr_RF, pred_tpr_RF, pred_thresholds_RF = metrics.roc_curve(y_test,pred)
  svm_fpr_RF, svm_tpr_RF, svm_thresholds_RF = metrics.roc_curve(y_test,svm_pred)
  import matplotlib.pyplot as plt
  # AUC
  auc_RF = metrics.roc_auc_score(y_test,y_pred)
  pred_auc_RF = metrics.roc_auc_score(y_test,pred)
  svm_auc_RF = metrics.roc_auc_score(y_test,svm_pred)
  plt.plot(fpr_RF, tpr_RF,'b-',label = f'Arbre de decision: AUC =({auc_RF})')
  plt.plot(pred_fpr_RF,pred_tpr_RF,'k-',label = f'Logistique regression: AUC =({pred_auc_RF})')
  plt.plot(svm_fpr_RF,svm_tpr_RF,'g-',label = f'SVM AUC =({svm_auc_RF})')
  
  # plt.plot([0,1],[0,1],'r-',label='random model')
  # plt.plot([0,0,1,1],[0,1,1,1],'g-',label='perfect model')
  plt.title('ROC Curve', fontsize=16)
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()

# %% [markdown]
# D'apres la courbe roc on remarque que les 3 modeles sont bons en terme de AUC et le modele arbre de décision est le meilleur car il a la valeur de AUC la plus élevée , mais  ça ne représente pas la réalité de notre dataset et de la performance des modeles car les classes sont désequilibrées et ya une sur-presentation de la classe 0 (non-fraud) par rapport a la classe 1 (fraud) autrement dit la majorité des observations du dataset sont classés non-fraudileuses et cela va entrainer des impacts sur la performance du modele predictif et cela veut dire que lors de l'entrainement du modele il va se focaliser que sur la classe majoritaire (non-fraud) en ignorant la classe minoritaire (fraud).

# %% [markdown]
# **SVM avec kernel**

# %% [markdown]
# SVM segmoid

# %%
from sklearn.svm import SVC 
# "Support vector classifier"
model = SVC(kernel="sigmoid")
model.fit(X_train_svm, y_train)
sigmoid_pred=model.predict(X_test_svm)

# %%
metrics_evaluation(y_test, sigmoid_pred)

# %% [markdown]
# SVM linear

# %%
from sklearn.svm import SVC 
# "Support vector classifier"
model = SVC(kernel="linear")
model.fit(X_train_svm, y_train)
linear_pred=model.predict(X_test_svm)

# %%
metrics_evaluation(y_test, linear_pred)

# %% [markdown]
# SVM Poly

# %%
from sklearn.svm import SVC 
# "Support vector classifier"
model = SVC(kernel="poly", degree=8)
model.fit(X_train_svm, y_train)
poly_pred=model.predict(X_test_svm)

# %%
metrics_evaluation(y_test, poly_pred)

# %% [markdown]
# **Comparaison de différentes approches de SVM en fonction de la courbe ROC et les métriques d'évaluation**

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
svm = metrics.confusion_matrix(y_test, svm_pred)
sigmoid_pred = metrics.confusion_matrix(y_test, sigmoid_pred)
lineair_pred= metrics.confusion_matrix(y_test, linear_pred)
poly_pred= metrics.confusion_matrix(y_test, poly_pred)
labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

fig.add_subplot(221)
plot_confusion_matrix(svm, labels, title="Confusion Matrix \n ( SVC sans kernel)", cmap=plt.cm.Reds)

fig.add_subplot(222)
plot_confusion_matrix(sigmoid_pred, labels, title="Confusion Matrix \n (SVC sigmoid)", cmap=plt.cm.Greens)

fig.add_subplot(223)
plot_confusion_matrix(lineair_pred, labels, title="Confusion Matrix \n (SVC linear)", cmap=plt.cm.Greens)

fig.add_subplot(224)
plot_confusion_matrix(poly_pred, labels, title="Confusion Matrix \n (SVC poly)", cmap=plt.cm.Blues)

# %% [markdown]
# En analysant les matrices de confusions des quatres modeles, on peut remarquer que le modele SVC sans kernel  il fait moins d'erreur (fautes) par rapport au autres modeles en terme de FP , le nombre de transactions fraudileuses qui ont été predites negative (non-fraud) et de FN le nombre de transactions non fraudileuses qui ont été predites fraud. et meme il donne aussi de bons résultats en terme de TP ( le nombre de transactions fraudileuses qui ont été predit comme fraud) et en terme de TN ( le nombre de transactions non fraudileuses qui ont été preditées comme non-fraud).

# %%
X = [
        [metrics.accuracy_score(y_test, svm_pred),metrics.recall_score(y_test, svm_pred), metrics.precision_score(y_test, svm_pred), metrics.f1_score(y_test, svm_pred)],
        [metrics.accuracy_score(y_test, sigmoid_pred),metrics.recall_score(y_test, sigmoid_pred),metrics.precision_score(y_test, sigmoid_pred), metrics.f1_score(y_test, sigmoid_pred)],
        [metrics.accuracy_score(y_test, linear_pred), metrics.recall_score(y_test, linear_pred), metrics.precision_score(y_test, linear_pred),metrics.f1_score(y_test, linear_pred)],
        [metrics.accuracy_score(y_test, poly_pred),metrics.recall_score(y_test, poly_pred), metrics.precision_score(y_test, poly_pred), metrics.f1_score(y_test, poly_pred)],
        
    ]
resultat = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['SVC(sans kernel)','SVC(sigmoid)','SVC(linear)','SVC(poly)'])
resultat

# %%
def curbe_ROC_SVM():
  fpr_RF, tpr_RF, thresholds_RF = metrics.roc_curve(y_test,svm_pred)
  sigmoid_fpr_RF, sigmoid_tpr_RF, sigmoid_thresholds_RF = metrics.roc_curve(y_test,sigmoid_pred)
  linear_fpr_RF, linear_tpr_RF, linear_thresholds_RF = metrics.roc_curve(y_test,linear_pred)
  poly_fpr_RF, poly_tpr_RF, poly_thresholds_RF = metrics.roc_curve(y_test,poly_pred)
  import matplotlib.pyplot as plt
  # AUC
  auc_RF = metrics.roc_auc_score(y_test,y_pred)
  sigmoid_auc_RF = metrics.roc_auc_score(y_test,sigmoid_pred)
  linear_auc_RF = metrics.roc_auc_score(y_test,linear_pred)
  poly_auc_RF = metrics.roc_auc_score(y_test,poly_pred)

  plt.plot(fpr_RF, tpr_RF,'b-',label = f'SVM sans kernel: AUC =({auc_RF})')
  plt.plot(sigmoid_fpr_RF,sigmoid_tpr_RF,'k-',label = f' SVM (sigmoid): AUC =({sigmoid_auc_RF})')
  plt.plot(linear_fpr_RF,linear_tpr_RF,'g-',label = f'SVM (linear): AUC =({linear_auc_RF})')
  poly_fpr_RF, poly_tpr_RF, poly_thresholds_RF = metrics.roc_curve(y_test,poly_pred)
  plt.plot(poly_fpr_RF,poly_tpr_RF,'r-',label = f'SVM (poly): AUC =({poly_auc_RF})')
  # plt.plot([0,1],[0,1],'r-',label='random model')
  # plt.plot([0,0,1,1],[0,1,1,1],'g-',label='perfect model')
  plt.title('ROC Curve', fontsize=16)
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()


curbe_ROC_SVM()

# %% [markdown]
# en compearant les différents modeles de SVC sans et avec kernel en fonction de AUC ,on a trouvé que le modele SVC avec kernel (linear) est un peu meilleur que SVM sans kernel et SVM poly , par contre SVM sigmoid est un peu moins bon. autrement dit que le SVM linear a trouvé la meilleure ou la droite la plus optimale (avec les vecteurs de support ) qui sépare toutes les données des deux classes .

# %% [markdown]
# **Question b :En utilisant la technique de GridSearch qui nous aide a trouver les best hyperparametres pour chaque model**

# %% [markdown]
# **Remarque :** en ce qui concerne la technique on a pas utilisé trop de parametres car ça va engendrer beaucoup de combinaison ce qui va rendre le temps d'execution trés lent et parfois ilimité

# %% [markdown]
# Arbre de décision

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
params = {
    "criterion":("gini", "entropy"), 
    "max_depth":list(range(2, 4)), 
    "min_samples_split":[2, 3], 
    "min_samples_leaf":list(range(1, 2)), 

}
tree_clf=DecisionTreeClassifier(random_state=42)
grid_search_cv = GridSearchCV(
    tree_clf,
     params,
     n_jobs=1,
     verbose=1,
     cv=2)
grid_search_cv.fit(X_train, y_train)

# %% [markdown]
# les meilleurs parametres pour trouver un bon model

# %%
# le meilleur parametre 
Tree_best_params=grid_search_cv.best_params_
grid_search_cv.best_score_, grid_search_cv.best_params_

# %%
tree_clf = DecisionTreeClassifier(**grid_search_cv.best_params_)
tree_clf.fit(X_train, y_train)
g_tree_pred=tree_clf.predict(X_test)

# %% [markdown]
# **Comparaison du modele Arbre de décision avec et sans la technique de gridsearch**

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
tree = metrics.confusion_matrix(y_test, y_pred)
g_tree = metrics.confusion_matrix(y_test, g_tree_pred)

labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

fig.add_subplot(221)
plot_confusion_matrix(tree, labels, title="Confusion Matrix \n ( Decision Tree) simple", cmap=plt.cm.Reds)

fig.add_subplot(222)
plot_confusion_matrix(g_tree, labels, title="Confusion Matrix \n (Decision Tree) with gridsearch", cmap=plt.cm.Greens)

# %% [markdown]
# En analysant les matrices de confusions des deux modeles avec et sans gridsearch, on peut remarquer que le modele Décision Tree avec gridsearch il fait un peu d'erreur (fautes) par rapport au modele simple en terme de FP , le nombre de transactions fraudileuses qui ont été predites negative (non-fraud) et de FN le nombre de transactions non fraudileuses qui ont été predites fraud. et meme il donne aussi de bons résultats en terme de TP ( le nombre de transactions fraudileuses qui ont été predit comme fraud) et en terme de TN ( le nombre de transactions non fraudileuses qui ont été preditées comme non-fraud).

# %%
X = [
        [metrics.accuracy_score(y_test, y_pred),metrics.recall_score(y_test, y_pred), metrics.precision_score(y_test, y_pred), metrics.f1_score(y_test, y_pred)],
        [metrics.accuracy_score(y_test, g_tree_pred),metrics.recall_score(y_test, g_tree_pred),metrics.precision_score(y_test, g_tree_pred), metrics.f1_score(y_test, g_tree_pred)],
        
    ]
resultat_tree = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['DecisionTree','DecisionTree(Gridsearch)'])
resultat_tree

# %%
import matplotlib.pyplot as plt
fpr_RF, tpr_RF, thresholds_RF = metrics.roc_curve(y_test,y_pred)
g_fpr_RF, g_tpr_RF, g_thresholds_RF = metrics.roc_curve(y_test, g_tree_pred)
  
# AUC
auc_RF = metrics.roc_auc_score(y_test,y_pred)
g_auc_RF = metrics.roc_auc_score(y_test, g_tree_pred)
plt.plot(fpr_RF, tpr_RF,'b-',label = f'DecisionTree: AUC =({auc_RF})')
plt.plot(g_fpr_RF,g_tpr_RF,'k-',label = f' DecisionTree (gridsearch): AUC =({g_auc_RF})')
plt.title('ROC Curve', fontsize=16)
plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %% [markdown]
# Aprés l'application de la technique GRridsearch sur le modele arbre de décision , cette technique nous a aidé a trouver les best hyper-parametres pour améliorer les résultat du modele en fonction des métriques d'évaluation et l'AUC, et donc on a obtenu AUC = 0.915

# %% [markdown]
# Logistic **Regression**

# %%
def Grid_search_logistique(X_train, y_train):
  LR_grid = {'penalty': ['l2', 'elasticnet'],
            'C': [0.25, 0.5, 0.75, 1, 0.1],
            'max_iter': [5000, 5500],
            'solver': ['lbfgs', 'liblinear']}

  log_reg = LogisticRegression()
  log_cv = GridSearchCV(
      log_reg, 
      LR_grid, 
      scoring="f1", 
      n_jobs=-1, 
  )
  log_grid=log_cv.fit(X_train, y_train)
  return log_grid
log_cv=Grid_search_logistique(X_train, y_train)

# %% [markdown]
# les meilleurs parametres pour trouver un bon model

# %%
Log_best_params=log_cv.best_params_
Log_best_params

# %%
log_reg = LogisticRegression(**log_cv.best_params_)
log_reg.fit(X_train, y_train)
reg_g_pred=log_reg.predict(X_test)

# %% [markdown]
# **Comparaison le modele Logistic regression avec et sans gridsearch**

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
reg = metrics.confusion_matrix(y_test, pred)
g_reg = metrics.confusion_matrix(y_test, reg_g_pred)
 
labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

fig.add_subplot(221)
plot_confusion_matrix(reg, labels, title="Confusion Matrix \n (Logistic regression) simple", cmap=plt.cm.Reds)

fig.add_subplot(222)
plot_confusion_matrix(g_reg, labels, title="Confusion Matrix \n (Logistic regression) with gridsearch", cmap=plt.cm.Greens)

# %%
X = [
        [metrics.accuracy_score(y_test, pred),metrics.recall_score(y_test, pred), metrics.precision_score(y_test, pred), metrics.f1_score(y_test, pred)],
        [metrics.accuracy_score(y_test, reg_g_pred),metrics.recall_score(y_test, reg_g_pred),metrics.precision_score(y_test, reg_g_pred), metrics.f1_score(y_test, reg_g_pred)],
        
    ]
resultat_log = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['Regression logistic','Regression logistic(Gridsearch)'])
resultat_log

# %%
import matplotlib.pyplot as plt
fpr_RF, tpr_RF, thresholds_RF = metrics.roc_curve(y_test,pred)
g_fpr_RF, g_tpr_RF, g_thresholds_RF = metrics.roc_curve(y_test, reg_g_pred)
  
# AUC
auc_RF = metrics.roc_auc_score(y_test,pred)
g_auc_RF = metrics.roc_auc_score(y_test, reg_g_pred)
plt.plot(fpr_RF, tpr_RF,'b-',label = f'Logistic regression: AUC =({auc_RF})')
plt.plot(g_fpr_RF,g_tpr_RF,'k-',label = f'Logistic regression (gridsearch): AUC =({g_auc_RF})')
plt.title('ROC Curve', fontsize=16)
plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %% [markdown]
# De meme avec Logistic regression , les meilleurs hyper-parametre nous a permet de trouver le modele avec la meilleur AUC qui est identique a celle de Logistique regression sans gridsearch. donc les deux modeles sont bons (identique) en terme de l'AUC

# %% [markdown]
# **Remarque**
#
# Gridsearch avec SVM ça prends beaucoup de temps , donc elle s'est pas executée

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.svm import SVC

# param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001, 0.00001, 10]} 

# clf_grid = GridSearchCV(SVC(), param_grid, verbose=0,cv=10)

# clf_grid.fit(X_train, y_train)

# %%
#clf_grid.best_params_

# %% [markdown]
# **Séance 3 Prédiction de churn, Partie II**

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(criterion='gini',
                                 n_estimators=5,
                                 random_state=1,
                                 n_jobs=2)
forest.fit(X_train, y_train)
forest_pred = forest.predict(X_test)

# %%
metrics_evaluation(y_test, forest_pred)

# %%
curbe_ROC(y_test, forest_pred)

# %% [markdown]
# XGBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(X_train, y_train)
B_pred=clf.predict(X_test)

# %%
metrics_evaluation(y_test, B_pred)

# %%
curbe_ROC(y_test, B_pred)

# %% [markdown]
# **Définition des variables (features) les plus importants**
#
# c'est une téchnique permet de determiner les variables les plus pertinenetes (en fonction des scores ) et celles qui sont faible afin d'améliorer les performances du modele.

# %%
def features_importance(X_train,feature_importance,modal_name):

    # Créer une liste de tuples (nom de la caractéristique, importance) pour chaque caractéristique
    feature_importance_tuples = [(X_train.columns[i], importance) for i, importance in enumerate(feature_importance)]

    # Trier la liste en fonction de l'importance (du plus grand au plus petit)
    feature_importance_tuples.sort(key=lambda x: x[1], reverse=True)

    # Afficher l'importance des caractéristiques avec leurs noms triés
    for feature, importance in feature_importance_tuples:
        print(f"Feature '{feature}': Importance = {importance:.4f}")

    # Plotter l'importance des caractéristiques sous forme de graphique à barres

    # Extraire les noms des caractéristiques et leurs importances triées
    feature_names = [feature[0] for feature in feature_importance_tuples]
    importances = [feature[1] for feature in feature_importance_tuples]

    # Plotter les importances des caractéristiques
    plt.bar(range(len(feature_names)), importances)
    plt.xticks(range(len(feature_names)), feature_names, rotation='vertical')
    plt.xlabel('Feature')
    plt.ylabel('Importance')
    plt.title(f'Importance des caractéristiques pour {modal_name}')
    plt.show()

# %% [markdown]
# **RandomForest**

# %%
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot

column=['scaled_time','scaled_amount','V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']
# define model
model = RandomForestClassifier()
# fit the model
model.fit(X_train, y_train)
# # get importance
# importance = model.feature_importances_
# # summarize feature importance
# for i,v in enumerate(importance):
#  print('Feature: %0d, Score: %.5f' % (i,v))
# # plot feature importance
# #plt.barh(df.columns,importance)
# pyplot.bar([x for x in column], importance)
# pyplot.show()
features_importance(X_train,model.feature_importances_)

# %% [markdown]
# pour le modele randomForest on peut determiner grace a ce graphe les variables les plus pertinentes (importantes) ayant des scores élevés telles que : V10,V12, V14,V17

# %% [markdown]
# **XGBoost**

# %%
from sklearn.ensemble import GradientBoostingClassifier
from matplotlib import pyplot

column=['scaled_time','scaled_amount','V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']

clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(X_train, y_train)
# get importance
importance_bg = clf.feature_importances_
for i,v in enumerate(importance_bg):
 print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
#plt.barh(column,importance_bg)
pyplot.bar([x for x in column], importance_bg)
pyplot.show()

# %% [markdown]
# pour le modele XGBoost , ya qu'une seule variable pertinente (V17) qu'elle a le score 1

# %% [markdown]
# **Arbre de décision**

# %%
from sklearn import tree
from matplotlib import pyplot

column=['scaled_time','scaled_amount','V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']
clf = tree.DecisionTreeClassifier()
# fit model
clf = clf.fit(X_train, y_train)
# get importance
importance_clf = clf.feature_importances_
# summarize feature importance
for i,v in enumerate(importance_clf):
 print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
#plt.barh(df.columns,importance)
pyplot.bar([x for x in column], importance_clf)
pyplot.show()

# %% [markdown]
# pareil pour le modele Arbre de décision , ya qu'une seule variable pertinente (V17) qu'elle a le score 0.49957 .

# %% [markdown]
# **Séance 4: Sur-échantillonage et sous-échantillonage**

# %% [markdown]
# La plupart des transactions (observations) sont non frauduleuses (99,83 %), tandis que les transactions frauduleuses se produisent (017 %) dans le dataframe.

# %%
import seaborn as sns
import plot as plt
colors = ["#0101DF", "#DF0101"]

sns.countplot(x='Class', data=df, palette=colors)
#plt.title('Class Distributions \n (0: No Fraud || 1: Fraud)', fontsize=14)
print('No Frauds', round(df['Class'].value_counts()[0]/len(df) * 100,2), '% of the dataset')
print('Frauds', round(df['Class'].value_counts()[1]/len(df) * 100,2), '% of the dataset')

# %% [markdown]
# **Random Under sampling**
# - cette technique permet de reduire le nombre d'instance de la classe majoriraire afin de rendre les classes plus équilibrées

# %%
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
Y=df['Class'] # target
mask=df.columns.shape[0]
features=df.columns[:mask-1]
X=df[features] # features
#print(Counter(Y))
# define oversampling strategy
undersample = RandomUnderSampler()
# fit and apply the transform
X_under, y_under = undersample.fit_resample(X, Y)
# summarize class distribution
#print(Counter(y_over))
X_under['Class']=y_under
#df=X_under.copy()
sns.countplot(x='Class', data=X_under, palette=colors)

# %% [markdown]
# Arbre de décision

# %%
from sklearn.model_selection import train_test_split
Y=X_under['Class'] # target
mask=X_under.columns.shape[0]
features=X_under.columns[:mask-1]
X=X_under[features] # features

under_X_train, under_X_test, under_y_train, under_y_test = train_test_split(X, Y, random_state=1, train_size = .7, stratify=Y)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(under_X_train, under_y_train)
#tree.plot_tree(clf)
under_y_pred=clf.predict(under_X_test)

# %%
metrics_evaluation(under_y_test, under_y_pred)

# %% [markdown]
# Regression Logistic

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='lbfgs', max_iter=3000)
log_reg.fit(under_X_train, under_y_train)
under_pred = log_reg.predict(under_X_test)

# %%
metrics_evaluation(under_y_test, under_pred)

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(criterion='gini',
                                 n_estimators=5,
                                 random_state=1,
                                 n_jobs=2)
forest.fit(under_X_train, under_y_train)
under_forest_pred = forest.predict(under_X_test)

# %%
metrics_evaluation(under_y_test, under_pred)

# %% [markdown]
# XGBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(X_train, y_train)
under_B_pred=clf.predict(under_X_test)

# %% [markdown]
# **Over-sampling (SMOTE)**
#
# *   Cette technique permet d'agmenter le nombre d'instances de la classe minoritaire

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, RandomizedSearchCV
Y=df['Class'] # target
mask=df.columns.shape[0]
features=df.columns[:mask-1]
X=df[features] # features
# SMOTE Technique (OverSampling) After splitting and Cross Validating
sm = SMOTE(sampling_strategy ='minority', random_state=42)
X_over, y_over = sm.fit_resample(X, Y)
X_over['Class']=y_over
sns.countplot(x='Class', data=X_over, palette=colors)

# %% [markdown]
# **Split le dataset**

# %%
from sklearn.model_selection import train_test_split
Y=X_over['Class'] # target
mask=X_over.columns.shape[0]
features=X_over.columns[:mask-1]
X=X_over[features] # features

over_X_train, over_X_test, over_y_train, over_y_test = train_test_split(X, Y, random_state=1, train_size = .7, stratify=Y)

# over_X_train=over_X_train[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']]

# over_X_test=over_X_test[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']]

# %% [markdown]
# Arbre de décision

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(over_X_train, over_y_train)
#tree.plot_tree(clf)
over_y_pred=clf.predict(over_X_test)

# %%
metrics_evaluation(over_y_test, over_y_pred)

# %% [markdown]
# Regression Logistic

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='lbfgs', max_iter=3000)
log_reg.fit(over_X_train, over_y_train)
over_pred = log_reg.predict(over_X_test)

# %%
metrics_evaluation(over_y_test, over_pred)

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(criterion='gini',
                                 n_estimators=5,
                                 random_state=1,
                                 n_jobs=2)
forest.fit(over_X_train, over_y_train)
over_forest_pred = forest.predict(over_X_test)

# %%
metrics_evaluation(over_y_test, over_forest_pred)

# %% [markdown]
# XGBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(X_train, y_train)
over_B_pred=clf.predict(over_X_test)

# %% [markdown]
# **Combinaison des deux techniques (under et over) de resampling**

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
over = RandomOverSampler(sampling_strategy=0.1)
Y=df['Class'] # target
X=df[features] # features
# fit and apply the transform
X_c, Y_c = over.fit_resample(X, Y)
print(Counter(Y_c))
under = RandomUnderSampler(sampling_strategy=0.5)
# fit and apply the transform
X_c, Y_c = under.fit_resample(X_c, Y_c)
print(Counter(Y_c))
X_c['Class']=Y_c
#df=X_over.copy()
sns.countplot(x='Class', data=X_c, palette=colors)

# %% [markdown]
# Split dataset

# %%
from sklearn.model_selection import train_test_split
Y=X_c['Class'] # target
mask=X_c.columns.shape[0]
features=X_c.columns[:mask-1]
X=X_c[features] # features

c_X_train, c_X_test, c_y_train, c_y_test = train_test_split(X, Y, random_state=1, train_size = .7, stratify=Y)

# c_X_train=c_X_train[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']]

# c_X_test=c_X_test[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']]

# %% [markdown]
# Arbre de decision

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(c_X_train, c_y_train)
#tree.plot_tree(clf)
c_y_pred=clf.predict(c_X_test)

# %%
metrics_evaluation(c_y_test, c_y_pred)

# %% [markdown]
# Regression logistic

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='lbfgs', max_iter=3000)
log_reg.fit(c_X_train, c_y_train)
c_pred = log_reg.predict(c_X_test)

# %%
metrics_evaluation(c_y_test, c_pred)

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(criterion='gini',
                                 n_estimators=5,
                                 random_state=1,
                                 n_jobs=2)
forest.fit(c_X_train, c_y_train)
c_forest_pred = forest.predict(c_X_test)

# %%
metrics_evaluation(c_y_test, c_forest_pred)

# %% [markdown]
# XGBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(X_train, y_train)
c_B_pred=clf.predict(c_X_test)

# %% [markdown]
# **Comparaison des modeles par rapport aux différentes approches (Under_sampling, Over-sampling et both )**

# %% [markdown]
# Comparaison par rapport a l'arbre de décision

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
under_arb = metrics.confusion_matrix(under_y_test, under_y_pred)
over_arb = metrics.confusion_matrix(over_y_test, over_y_pred)
c_arb = metrics.confusion_matrix(c_y_test, c_y_pred)
labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

fig.add_subplot(221)
plot_confusion_matrix(under_arb, labels, title="Confusion Matrix \n (DecisionTree) with under-sampling", cmap=plt.cm.Reds)

fig.add_subplot(222)
plot_confusion_matrix(over_arb, labels, title="Confusion Matrix \n (DecisionTree) with Over-sampling", cmap=plt.cm.Greens)

fig.add_subplot(223)
plot_confusion_matrix(c_arb, labels, title="Confusion Matrix \n (DecisionTree) with both-sampling", cmap=plt.cm.Blues)

# %% [markdown]
# En analysant les matrices de confusions des trois approches on peut remarquer que le modele Décisiontree  pour l'approche under-sampling il fait un peu d'erreur en terme de FP , le nombre de transactions fraudileuses qui ont été predites negative (non-fraud) et de FN, le nombre de transactions non fraudileuses qui ont été predites fraud.

# %%
X = [
        
        [metrics.accuracy_score(under_y_test, under_y_pred),metrics.recall_score(under_y_test, under_y_pred),metrics.precision_score(under_y_test, under_y_pred), metrics.f1_score(under_y_test, under_y_pred)],
        [metrics.accuracy_score(over_y_test, over_y_pred),metrics.recall_score(over_y_test, over_y_pred),metrics.precision_score(over_y_test, over_y_pred), metrics.f1_score(over_y_test, over_y_pred)],
        [metrics.accuracy_score(c_y_test, c_y_pred),metrics.recall_score(c_y_test, c_y_pred),metrics.precision_score(c_y_test, c_y_pred), metrics.f1_score(c_y_test, c_y_pred)],
    ]
resultat_sampling = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['DecisionTree(under_sampling)','DecisionTree(over_sampling)','DecisionTree(both_sampling)'])
resultat_sampling

# %%
  under_fpr_RF, under_tpr_RF, under_thresholds_RF = metrics.roc_curve(under_y_test,under_y_pred)
  over_fpr_RF, over_tpr_RF, over_thresholds_RF = metrics.roc_curve(over_y_test,over_y_pred)
  c_fpr_RF, c_tpr_RF, c_thresholds_RF = metrics.roc_curve(c_y_test,c_y_pred)
  import matplotlib.pyplot as plt
  # AUC
  under_auc_RF = metrics.roc_auc_score(under_y_test,under_y_pred)
  over_auc_RF = metrics.roc_auc_score(over_y_test,over_y_pred)
  c_auc_RF = metrics.roc_auc_score(c_y_test,c_y_pred)

  plt.plot(under_fpr_RF,under_tpr_RF,'k-',label = f' DecisionTree (under): AUC =({under_auc_RF})')
  plt.plot(over_fpr_RF,over_tpr_RF,'g-',label = f'DecisionTree (Over): AUC =({over_auc_RF})')
  plt.plot(c_fpr_RF,c_tpr_RF,'r-',label = f'DecisionTree (both): AUC =({c_auc_RF})')
  plt.title('ROC Curve', fontsize=16)
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()

# %% [markdown]
# en comparant le modele arbre de décision avec les 3 différentes approches on a trouvé que la meilleures approches pour lesquelles le modele est performant (en fonction de AUC ) sont celles de Over-sampling et Both-sampmling .
#
# par contre on trouve l'approche de under-sampling est moins bonne car elle consiste a supprimer les transactions de la classe majoritaire (non-fraud) et probablement ça peut entrainer une perte d'information.
#
# **Remarque :** pour le over-sampling ça peut entrainer un sur-ajustement (overfitting) .

# %% [markdown]
# **Comparaison du modele regression logistique par rapport aux différentes approches**

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
under_log = metrics.confusion_matrix(under_y_test, under_pred)
over_log = metrics.confusion_matrix(over_y_test, over_pred)
c_log = metrics.confusion_matrix(c_y_test, c_pred)
labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

fig.add_subplot(221)
plot_confusion_matrix(under_log, labels, title="Confusion Matrix \n (Regression Logistic) with under-sampling", cmap=plt.cm.Reds)

fig.add_subplot(222)
plot_confusion_matrix(over_log, labels, title="Confusion Matrix \n (Regression Logistic) with Over-sampling", cmap=plt.cm.Greens)

fig.add_subplot(223)
plot_confusion_matrix(c_log, labels, title="Confusion Matrix \n (Regression Logistic) with both-sampling", cmap=plt.cm.Blues)

# %% [markdown]
# En analysant les matrices de confusions des trois approches on peut remarquer que le modele Logistic Regression pour l'approche under-sampling il fait pas beaucoup d'erreur par rapport aux autres en terme de FP = 16 , le nombre de transactions fraudileuses qui ont été predites negative (non-fraud) et de FN =4, le nombre de transactions non fraudileuses qui ont été predites fraud.

# %%
X = [
        
        [metrics.accuracy_score(under_y_test, under_pred),metrics.recall_score(under_y_test, under_pred),metrics.precision_score(under_y_test, under_pred), metrics.f1_score(under_y_test, under_pred)],
        [metrics.accuracy_score(over_y_test, over_pred),metrics.recall_score(over_y_test, over_pred),metrics.precision_score(over_y_test, over_pred), metrics.f1_score(over_y_test, over_pred)],
        [metrics.accuracy_score(c_y_test, c_pred),metrics.recall_score(c_y_test, c_pred),metrics.precision_score(c_y_test, c_pred), metrics.f1_score(c_y_test, c_pred)],
    ]
resultat_log_sampling = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['Logistic regression(under_sampling)','Logistic regression (over_sampling)','Logistic regression (both_sampling)'])
resultat_log_sampling

# %% [markdown]
# la courbe ROC

# %%
  under_fpr_RF, under_tpr_RF, under_thresholds_RF = metrics.roc_curve(under_y_test,under_pred)
  over_fpr_RF, over_tpr_RF, over_thresholds_RF = metrics.roc_curve(over_y_test,over_pred)
  c_fpr_RF, c_tpr_RF, c_thresholds_RF = metrics.roc_curve(c_y_test,c_pred)
  import matplotlib.pyplot as plt
  # AUC
  under_auc_RF = metrics.roc_auc_score(under_y_test,under_pred)
  over_auc_RF = metrics.roc_auc_score(over_y_test,over_pred)
  c_auc_RF = metrics.roc_auc_score(c_y_test,c_pred)

  plt.plot(under_fpr_RF,under_tpr_RF,'k-',label = f'Logistic regression (under): AUC =({under_auc_RF})')
  plt.plot(over_fpr_RF,over_tpr_RF,'g-',label = f'Logistic regression (Over): AUC =({over_auc_RF})')
  plt.plot(c_fpr_RF,c_tpr_RF,'r-',label = f'Logistic regression (both): AUC =({c_auc_RF})')
  plt.title('ROC Curve', fontsize=16)
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()

# %% [markdown]
# on peut remarquer que les trois approches sont bonnes en fonction des metriques d'évaluation de performance tels que : Recall, Accuracy, Précision et l'AUC. le modele logistic regression pour l'approche over-sampling est un peur meilleure en terme de AUC

# %% [markdown]
# **Comparaison par rapport au modele Random Forest**

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
under_forest = metrics.confusion_matrix(under_y_test, under_forest_pred)
over_forest = metrics.confusion_matrix(over_y_test, over_forest_pred)
c_forest = metrics.confusion_matrix(c_y_test, c_forest_pred)
labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

fig.add_subplot(221)
plot_confusion_matrix(under_forest, labels, title="Confusion Matrix \n (RandomForest) with under-sampling", cmap=plt.cm.Reds)

fig.add_subplot(222)
plot_confusion_matrix(over_forest, labels, title="Confusion Matrix \n (RandomForest) with Over-sampling (SMOTE)", cmap=plt.cm.Greens)

fig.add_subplot(223)
plot_confusion_matrix(c_forest, labels, title="Confusion Matrix \n (RandomForest) with both-sampling", cmap=plt.cm.Blues)

# %% [markdown]
# En analysant les matrices de confusions des trois approches on peut remarquer que le modele RandomForest pour l'approche both-sampling il fait pas beaucoup d'erreur en terme de FP = 0 , le nombre de transactions fraudileuses qui ont été predites negative (non-fraud) et de FN =5, le nombre de transactions non fraudileuses qui ont été predites fraud.

# %%
X = [
        
        [metrics.accuracy_score(under_y_test, under_forest_pred),metrics.recall_score(under_y_test, under_forest_pred),metrics.precision_score(under_y_test, under_forest_pred), metrics.f1_score(under_y_test, under_forest_pred)],
        [metrics.accuracy_score(over_y_test, over_forest_pred),metrics.recall_score(over_y_test, over_forest_pred),metrics.precision_score(over_y_test, over_forest_pred), metrics.f1_score(over_y_test, over_forest_pred)],
        [metrics.accuracy_score(c_y_test, c_forest_pred),metrics.recall_score(c_y_test, c_forest_pred),metrics.precision_score(c_y_test, c_forest_pred), metrics.f1_score(c_y_test, c_forest_pred)],
    ]
resultat_forest_sampling = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['Random Forest(under_sampling)','Random Forest (over_sampling)','Random Forest (both_sampling)'])
resultat_forest_sampling

# %%
  under_fpr_RF, under_tpr_RF, under_thresholds_RF = metrics.roc_curve(under_y_test,under_forest_pred)
  over_fpr_RF, over_tpr_RF, over_thresholds_RF = metrics.roc_curve(over_y_test,over_forest_pred)
  c_fpr_RF, c_tpr_RF, c_thresholds_RF = metrics.roc_curve(c_y_test,c_forest_pred)
  import matplotlib.pyplot as plt
  # AUC
  under_auc_RF = metrics.roc_auc_score(under_y_test,under_forest_pred)
  over_auc_RF = metrics.roc_auc_score(over_y_test,over_forest_pred)
  c_auc_RF = metrics.roc_auc_score(c_y_test,c_forest_pred)

  plt.plot(under_fpr_RF,under_tpr_RF,'k-',label = f'Random Forest (under): AUC =({under_auc_RF})')
  plt.plot(over_fpr_RF,over_tpr_RF,'g-',label = f'Random Forest (Over): AUC =({over_auc_RF})')
  plt.plot(c_fpr_RF,c_tpr_RF,'r-',label = f'Random Forest (both): AUC =({c_auc_RF})')
  plt.title('ROC Curve', fontsize=16)
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()

# %% [markdown]
# en comparant le modele RandomForest avec les 3 différentes approches on a trouvé que la meilleures approches pour lesquelles le modele est performant (en fonction de AUC ) sont celles de Over-sampling et Both-sampmling .
#
# par contre on trouve l'approche de under-sampling est moins bonne car elle consiste a supprimer les transactions de la classe majoritaire (non-fraud) et probablement ça peut entrainer une perte d'information.
#
# **Remarque :** pour le over-sampling ça peut entrainer un sur-ajustement (overfitting) .

# %% [markdown]
# **Comparaison par rapport au modele XGBoost**

# %%
X = [
        
        [metrics.accuracy_score(under_y_test, under_B_pred),metrics.recall_score(under_y_test, under_B_pred),metrics.precision_score(under_y_test, under_B_pred), metrics.f1_score(under_y_test, under_B_pred)],
        [metrics.accuracy_score(over_y_test, over_B_pred),metrics.recall_score(over_y_test, over_B_pred),metrics.precision_score(over_y_test, over_B_pred), metrics.f1_score(over_y_test, over_B_pred)],
        [metrics.accuracy_score(c_y_test, c_B_pred),metrics.recall_score(c_y_test, c_B_pred),metrics.precision_score(c_y_test, c_B_pred), metrics.f1_score(c_y_test, c_B_pred)],
    ]
resultat_B_sampling = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['XGBoost(under_sampling)','XGBoost(over_sampling SMOTE)','XGBoost (both_sampling)'])
resultat_B_sampling

# %%
  under_fpr_RF, under_tpr_RF, under_thresholds_RF = metrics.roc_curve(under_y_test,under_B_pred)
  over_fpr_RF, over_tpr_RF, over_thresholds_RF = metrics.roc_curve(over_y_test, over_B_pred)
  c_fpr_RF, c_tpr_RF, c_thresholds_RF = metrics.roc_curve(c_y_test,c_B_pred)
  import matplotlib.pyplot as plt
  # AUC
  under_auc_RF = metrics.roc_auc_score(under_y_test,under_B_pred)
  over_auc_RF = metrics.roc_auc_score(over_y_test,over_B_pred)
  c_auc_RF = metrics.roc_auc_score(c_y_test,c_B_pred)

  plt.plot(under_fpr_RF,under_tpr_RF,'k-',label = f'XGBoost (under): AUC =({under_auc_RF})')
  plt.plot(over_fpr_RF,over_tpr_RF,'g-',label = f'XGBoost (Over): AUC =({over_auc_RF})')
  plt.plot(c_fpr_RF,c_tpr_RF,'r-',label = f'XGBoost (both): AUC =({c_auc_RF})')
  plt.title('ROC Curve', fontsize=16)
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()

# %% [markdown]
# **b/- en utilisant gridsearch pour trouver les meilleures hyper-parametres**
#
# **Remarque :** ce qui concernene les parametres de gridsearch , On a pas utilisé beaucoup de combinaison en raison de temps d'execution du modele qui sera trés grand est presque ilimité

# %% [markdown]
# **Random Under-sampling**

# %% [markdown]
# Arbre de décision

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
params = {
    "criterion":("gini", "entropy"), 
    "max_depth":list(range(4, 7)), 
    "min_samples_split":[3, 7], 
    "min_samples_leaf":list(range(4, 6)), 

}
tree_clf=DecisionTreeClassifier(random_state=42)
grid_search_cv = GridSearchCV(
    tree_clf,
     params,
     n_jobs=1,
     verbose=1,
     cv=2)
grid_search_cv.fit(under_X_train, under_y_train)

# %%
# le meilleur parametre 
grid_search_cv.best_score_, grid_search_cv.best_params_

# %%
tree_clf = DecisionTreeClassifier(**grid_search_cv.best_params_)
tree_clf.fit(under_X_train, under_y_train)
under_g_tree_pred=tree_clf.predict(under_X_test)

# %%
metrics_evaluation(under_y_test, under_g_tree_pred)

# %% [markdown]
# Logistic Regression

# %%
lg_grid=Grid_search_logistique(under_X_train, under_y_train)
log_reg = LogisticRegression(**lg_grid.best_params_)
log_reg.fit(under_X_train, under_y_train)
under_g_lg_pred=log_reg.predict(under_X_test)

# %%
metrics_evaluation(under_y_test, under_g_lg_pred)

# %% [markdown]
# **Oversampling(SMOTE) with grid search**

# %% [markdown]
# Arbre de décision

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
params = {
    "criterion":("entropy","gini"), 
    "max_depth":list(range(6, 8)), 
    "min_samples_split":[5, 7], 
    "min_samples_leaf":list(range(5, 7)), 

}
tree_clf=DecisionTreeClassifier(random_state=42)
grid_search_cv = GridSearchCV(
    tree_clf,
     params,
     n_jobs=1,
     verbose=1,
     cv=2)
grid_search_cv.fit(over_X_train, over_y_train)

# %%
# le meilleur parametre 
grid_search_cv.best_score_, grid_search_cv.best_params_

# %%
tree_clf = DecisionTreeClassifier(**grid_search_cv.best_params_)
tree_clf.fit(over_X_train, over_y_train)
over_g_tree_pred=tree_clf.predict(over_X_test)

# %%
metrics_evaluation(over_y_test, over_g_tree_pred)

# %% [markdown]
# Logistic regression

# %%
lg_over_grid=Grid_search_logistique(over_X_train, over_y_train)
log_over_reg = LogisticRegression(**lg_over_grid.best_params_)
log_over_reg.fit(over_X_train, over_y_train)
over_g_lg_pred=log_reg.predict(over_X_test)

# %% [markdown]
# **Comparaison Simple DecisionTree avec et sans gridsearch pour l'approche over-sampling (SMOTE) et Random-under-sampling**

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
tree = metrics.confusion_matrix(over_y_test,  over_y_pred)
g_tree = metrics.confusion_matrix(over_y_test, over_g_tree_pred)
under_tree = metrics.confusion_matrix(under_y_test,  under_y_pred)
under_g_tree = metrics.confusion_matrix(under_y_test, under_g_tree_pred)
labels = ['No Fraud', 'Fraud']

fig = plt.figure(figsize=(16,8))

fig.add_subplot(221)
plot_confusion_matrix(tree, labels, title="Confusion Matrix \n (Simple DecisionTree) with Over-sampling", cmap=plt.cm.Reds)

fig.add_subplot(222)
plot_confusion_matrix(g_tree, labels, title="Confusion Matrix \n (DecisionTree with gridsearch) with Over-sampling", cmap=plt.cm.Greens)
fig.add_subplot(223)
plot_confusion_matrix(under_tree, labels, title="Confusion Matrix \n (DecisionTree) with Under-sampling", cmap=plt.cm.Greens)
fig.add_subplot(224)
plot_confusion_matrix(under_g_tree, labels, title="Confusion Matrix \n (DecisionTree grid search) with Under-sampling", cmap=plt.cm.Blues)

# %% [markdown]
# en regardant la matrice de confusion des deux approches  , on peut remarquer que le modele DecisionTree simple est meilleur que DecisionTree with gridsearch dans la case de TN (true negative) qu'est le nombre de transactions non fraudileuses qui on été predites positive (fraud). cette case est trés élevé dans le modele de decisionTree with gridsearch. ce qui va enrainer par exemple des bloquages des cartes des clients qui font des achats puisque le modele il va considerer que leur transactions est fraudileuses alores en realité elles sont pas.
# la meme remarque pour la case FP (false positive) qui exprime le nombre de transactions fraudileuses qui ont été predites négative (non-fraud).

# %%
X = [
        [metrics.accuracy_score(over_y_test, over_y_pred),metrics.recall_score(over_y_test, over_y_pred),metrics.precision_score(over_y_test, over_y_pred), metrics.f1_score(over_y_test, over_y_pred)],
        [metrics.accuracy_score(over_y_test, over_g_tree_pred),metrics.recall_score(over_y_test, over_g_tree_pred),metrics.precision_score(over_y_test, over_g_tree_pred), metrics.f1_score(over_y_test, over_g_tree_pred)],
       [metrics.accuracy_score(under_y_test, under_y_pred),metrics.recall_score(under_y_test, under_y_pred),metrics.precision_score(under_y_test, under_y_pred), metrics.f1_score(under_y_test, under_y_pred)],
     [metrics.accuracy_score(over_y_test, over_g_tree_pred),metrics.recall_score(over_y_test, over_g_tree_pred),metrics.precision_score(under_y_test, under_g_tree_pred), metrics.f1_score(under_y_test, under_g_tree_pred)],
    ]
resultat_over_g_decision = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['decision Tree(over_sampling)','avec gridsearch(over_sampling)','decision Tree(under_sampling)','avec gridsearch(over_sampling)'])
resultat_over_g_decision

# %%
  over_fpr_RF, over_tpr_RF, over_thresholds_RF = metrics.roc_curve(over_y_test,over_y_pred)
  over_g_fpr_RF, over_g_tpr_RF, over_g_thresholds_RF = metrics.roc_curve(over_y_test,over_g_tree_pred)
  under_fpr_RF, under_tpr_RF, under_thresholds_RF = metrics.roc_curve(under_y_test,under_y_pred)
  under_g_fpr_RF, under_g_tpr_RF, under_g_thresholds_RF = metrics.roc_curve(under_y_test,under_g_tree_pred)
  import matplotlib.pyplot as plt
  # AUC
  over_auc_RF = metrics.roc_auc_score(over_y_test, over_y_pred)
  over_g_auc_RF = metrics.roc_auc_score(over_y_test, over_g_tree_pred)
  under_auc_RF = metrics.roc_auc_score(under_y_test, under_y_pred)
  under_g_auc_RF = metrics.roc_auc_score(under_y_test, under_g_tree_pred)
   
  plt.plot(over_fpr_RF,over_tpr_RF,'k-',label = f'DecisionTree (over): AUC =({over_auc_RF})')
  plt.plot(over_g_fpr_RF,over_g_tpr_RF,'g-',label = f'DecisionTree with gridsearch (over): AUC =({over_g_auc_RF})')

  plt.plot(under_fpr_RF,under_tpr_RF,'r-',label = f'DecisionTree (under): AUC =({under_auc_RF})')
  plt.plot(under_g_fpr_RF,under_g_tpr_RF,'o-',label = f'DecisionTree with gridsearch (under): AUC =({under_g_auc_RF})')
 
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()

# %% [markdown]
# En comparant le modèle Decision Tree  avec les 4 différentes approches avec et sans gridsearch  on a trouvé que les meilleures approches pour lesquelles le modèle est performant (en fonction de AUC ) sont celles de Over-sampling avec et sans grid search.
#
# D'apres la courbe roc on remarque que le modele over DecisionTree est meilleur que celui de gridsearch malgré qu'on trouvé les best hyper-parametre pour le modele.
#
# **Remarque:**
# lors de la recherche des meileures hyper-parametres par gridsearch on a pas mets beaucoup de parametres car plus le nombre de parametre est grand plus y'aura des combinaisons et ce qui va augmenter le temps d'execution et donc le gridsearch ne termine pas son exécution.

# %% [markdown]
# **Comparaison Logistic regression avec et sans gridsearch pour l'approche over-sampling (SMOTE) et Random-under-sampling**

# %%
X = [
        [metrics.accuracy_score(over_y_test, over_pred),metrics.recall_score(over_y_test, over_pred),metrics.precision_score(over_y_test, over_pred), metrics.f1_score(over_y_test, over_pred)],
        [metrics.accuracy_score(over_y_test, over_g_lg_pred),metrics.recall_score(over_y_test, over_g_lg_pred),metrics.precision_score(over_y_test, over_g_lg_pred), metrics.f1_score(over_y_test, over_g_lg_pred)],
       [metrics.accuracy_score(under_y_test, under_pred),metrics.recall_score(under_y_test, under_pred),metrics.precision_score(under_y_test, under_pred), metrics.f1_score(under_y_test,under_pred)],
     [metrics.accuracy_score(under_y_test, under_g_lg_pred),metrics.recall_score(under_y_test, under_g_lg_pred),metrics.precision_score(under_y_test, under_g_lg_pred), metrics.f1_score(under_y_test, under_g_lg_pred)],
    ]
resultat_under_g_decision = pd.DataFrame(data=X, columns=['Accuracy', 'Recall', 'Precision', 'f1_score'], index = ['Logistic regression (over_sampling)','avec gridsearch(over_sampling)',' Logistic regression(under_sampling)','avec gridsearch(under_sampling)'])
resultat_under_g_decision

# %%
  over_fpr_RF, over_tpr_RF, over_thresholds_RF = metrics.roc_curve(over_y_test,over_pred)
  over_g_fpr_RF, over_g_tpr_RF, over_g_thresholds_RF = metrics.roc_curve(over_y_test, over_g_lg_pred)
  under_fpr_RF, under_tpr_RF, under_thresholds_RF = metrics.roc_curve(under_y_test,under_pred)
  under_g_fpr_RF, under_g_tpr_RF, under_g_thresholds_RF = metrics.roc_curve(under_y_test, under_g_lg_pred)
  import matplotlib.pyplot as plt
  # AUC
  over_auc_RF = metrics.roc_auc_score(over_y_test, over_pred)
  over_g_auc_RF = metrics.roc_auc_score(over_y_test, over_g_lg_pred)
  under_auc_RF = metrics.roc_auc_score(under_y_test, under_pred)
  under_g_auc_RF = metrics.roc_auc_score(under_y_test, under_g_lg_pred)
   
  plt.plot(over_fpr_RF,over_tpr_RF,'k-',label = f'Logistic regression (over): AUC =({over_auc_RF})')
  plt.plot(over_g_fpr_RF,over_g_tpr_RF,'g-',label = f'Logistic regression  with gridsearch (over): AUC =({over_g_auc_RF})')

  plt.plot(under_fpr_RF,under_tpr_RF,'r-',label = f'Logistic regression  (under): AUC =({under_auc_RF})')
  plt.plot(under_g_fpr_RF,under_g_tpr_RF,'o-',label = f'Logistic regression  with gridsearch (under): AUC =({under_g_auc_RF})')
 
  plt.legend()
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.show()

# %% [markdown]
# En comparant le modèle Logistic regression  avec les 4 différentes approches avec et sans gridsearch  on a trouvé que les meilleures approches pour lesquelles le modèle est performant (en fonction de AUC ) sont celles de Over-sampling avec et sans grid search.
#
# **Remarque:**
# lors de la recherche des meileures hyper-parametres par gridsearch on a pas mets beaucoup de parametres car plus le nombre de parametre est grand plus y'aura des combinaisons et ce qui va augmenter le temps d'execution et donc le gridsearch ne termine pas son exécution.
